# %% [markdown]
# <a href="https://colab.research.google.com/github/cbandrowski/CSC467_Mod1_Assignment/blob/main/Module1_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module 1 Assignment

# %%
#import cv2
# Opencv Library for Image processing
import cv2
#import numpy as np
#NumPy Library mathematical Functions
import numpy as np
#from mpl_toolkits import mplot3d
#2D and 3D visualizations
from mpl_toolkits import mplot3d
#from skimage import io as io_url
#For simplified image I/O operations
from skimage import io as io_url
# Import the matplotlib library and pyplot module
import matplotlib.pyplot as plt

# %% [markdown]
# Quadratic Equation

# %%
# Generate x values
x = np.linspace(-10, 10, 100)

# Quadratic equation: y = x^2 - 8x - 5
y = x**2 - 8*x - 5

# Plotting the graph
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='y = x^2 - 8x - 5', color='red')
plt.title('Quadratic Equation Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Image

# %%
# Load the image file (update the path to your image)
frame = io_url.imread('https://preview.redd.it/official-solo-leveling-season-2-key-visual-wallpaper-v0-iymxfnoaf3pd1.jpeg?auto=webp&s=3ca4c3396c2ee208f158e594ff79f7161fed886e')
frame = np.float32(frame) / 255

plt.imshow(frame)
plt.show()
